# %% [markdown]
# # APS 2 de TRANSFERÊNCIA DE CALOR E MECÂNICA DOS SÓLIDOS
#
# ### ALunos: Daniel Delattre & Guilherme Carvalho

# %%
import numpy as np
from matplotlib import pyplot as plt
from math import *
from numpy import *

# %% [markdown]
# ## Formularizando ( atividade 1 )

# %% [markdown]
# ![](formula1.png)

# %% [markdown]
# ![](atv1.jpeg)

# %% [markdown]
# ## Atividade 2

# %%
#dados do enunciado
tolerancia       = 1e-10   #?
L                = 0.3     #m
D                = 0.005   #m diametro
raio             = D/2
densidade        = 2700    #kg/m³
condutividade    = 180     #W/mK  k 
calor_especifico = 896     #J/kgK
perimetro = 2*pi*raio
area      = pi*(raio**2)
Te  = 25  #extremidade ºC
Tb  = 100 #Temperatura base ºC
Ta  = 25  #temperatura ambiente
h   = 100 #W/m²K coeficiente convecção
dx = 300e-3/10 
alpha = condutividade/(densidade*calor_especifico)  # difusividade térmica  [m2/s]
dt = (dx**2)/(alpha*((h*perimetro*(dx**2))/(condutividade*area)+2))
# intervalo espacial
x = np.arange(0, L+dx, dx) 
t = np.arange(0, 1000+dt, dt) 
print(len(x))
print(len(t))
#Temperatura
T = np.zeros((200,11)) #criando matriz de zeros
T[:,0] = T[-1] = Tb
T[:,1:len(x)] = Ta
erro = 100
for l in range(1, len(t)):
    for i in range(1, len(x) -1):
        T[l,i] = (alpha*dt/dx**2)*(T[l-1,i+1] - 2*T[l-1,i] + T[l-1,i-1]) - ((h*perimetro*alpha*dt)/(condutividade*area))*(T[l-1,i] - Ta) +T[l-1,i]
    erro = max(abs((T[l,1:-1] - T[l-1,1:-1])/T[l,1:-1]))

    if erro<tolerancia:
        break
plt.plot(x, T[l],"r")
plt.grid()
plt.xlabel("x [M]")
plt.ylabel("T [°C]")
plt.show()
# Out:
# 11
# 200

# %% [markdown]
# ## Atividade 3 (Gráfico comparativo)

# %%
m = sqrt((h*perimetro)/(condutividade*area))
teta_l = 25 - Ta
teta_b = Tb - Ta
teta_l/teta_b
T2 = []
for i in range(len(x)):
    eq = (teta_l*sinh(m*x[i])+ teta_b*sinh(m*(L-x[i])))/(sinh(m*L)) + Ta      
    T2.append(eq)
plt.plot(x, T2,"ro")
plt.xlabel("x [m]")
plt.grid()
plt.ylabel("T [°C]")
plt.show()

# %% [markdown]
# ## Conclusão
#
# #### Concluimos que o modelo desenvolvido se aproxima bastante da realidade, pois os gráficos ficaram com resultados bem próximos.

# %%
plt.plot(x, T[l],"r",label="Metodo das diferenças finitas")
plt.plot(x, T2,"bo",label="Analitica")
plt.xlabel("x [m]")
plt.grid()
plt.ylabel("T [°C]")
plt.legend()
plt.show()

# %%
#testenado git
